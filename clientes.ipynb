# %% [markdown]
# <a href="https://colab.research.google.com/github/gaby1719/etl-data-pipeline/blob/main/clientes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://github.com/gaby1719/datawarehouse-seguros.git

# %%
import pandas as pd

# %% [markdown]
# BLOQUE 1: CARGA DEL DATASET

# %%
#Ruta del dataset almacenada en GitHub
url = "https://raw.githubusercontent.com/gaby1719/datawarehouse-seguros/refs/heads/main/data/clientes.csv"

# %%
#Lectura del Archivo
df = pd.read_csv(url)
print("Dataset Cargado Correctamente")
# Out:
# Dataset Cargado Correctamente

# %%
display(df.head())
# Out:
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %% [markdown]
# BLOQUE 2: Exploración del DATASET

# %%
print("Primeras filas del dataset")
display(df.head())
# Out:
# Primeras filas del dataset
#    id_cliente                 nombre                             email  \
# 0           1      José Chávez Pérez      jose.chavez.perez1@gmail.com
# 1           2    Daniela Rojas Ortiz    daniela.rojas.ortiz2@seguro.sv
# 2           3    Ricardo Cruz Flores  ricardo.cruz.flores3@example.com
# 3           4      María Pérez Pérez     maria.perez.perez4@correo.com
# 4           5  Fernanda Chávez Rojas  fernanda.chavez.rojas5@seguro.sv
#
#       genero fecha_nacimiento          ciudad segmento
# 0     Hombre       2011/11/24       SanMiguel      NaN
# 1        NaN         01-02-80        Sta. Ana      NaN
# 2  Masculino         06-18-79       S. Miguel      NaN
# 3  Masculino       1960-09-29      LaLibertad  REGULAR
# 4        NaN       1945/08/02   San Salvador      Pyme

# %%
print("Dimensiones del dataset (filas, columnas)")
print(df.shape)
# Out:
# Dimensiones del dataset (filas, columnas)
# (3030, 7)

# %%
print("Columnas del dataset")
print(df.columns)
# Out:
# Columnas del dataset
# Index(['id_cliente', 'nombre', 'email', 'genero', 'fecha_nacimiento', 'ciudad',
#        'segmento'],
#       dtype='object')

# %%
print("Tipo de datos")
print(df.dtypes)
# Out:
# Tipo de datos
# id_cliente           int64
# nombre              object
# email               object
# genero              object
# fecha_nacimiento    object
# ciudad              object
# segmento            object
# dtype: object

# %%
print("Valores nulos por columnas")
print(df.isnull().sum())
# Out:
# Valores nulos por columnas
# id_cliente            0
# nombre                0
# email                 0
# genero              595
# fecha_nacimiento      0
# ciudad                0
# segmento            597
# dtype: int64

# %%
print("Registros duplicados")
print(df.duplicated().sum())
# Out:
# Registros duplicados
# 0

# %% [markdown]
# BLOQUE 3: LIMPIEZA DE DATOS

# %%
#Elimionar espacios al inicio y al final del texto
for col in df.select_dtypes(include="object").columns:df[col]=df[col].str.strip()

# %%
#Normalizar el nombre
df["nombre"]=df["nombre"].str.title()

# %%
#Normalizar el email
df["email"]=df["email"].str.lower()

# %%
#Normalizar genero
df["genero"]=df["genero"].str.upper()

# %%
#Convertir fecha de nacimiento a formato fecha
df['fecha_nacimiento']=pd.to_datetime(df['fecha_nacimiento'],errors="coerce")

# %%
#Normalizar ciudad
df["ciudad"]=df['ciudad'].str.title()
df['ciudad']=df['ciudad'].astype(str)
df['ciudad']=df['ciudad'].str.strip()
df['ciudad']=df['ciudad'].str.upper()

# %%
#Limpieza de segmento
df['segmento']=df['segmento'].astype(str)
df['segmento']=df['segmento'].str.strip()
df['segmento']=df['segmento'].str.upper()

# %%
for col in df.columns: print(col)
# Out:
# id_cliente
# nombre
# email
# genero
# fecha_nacimiento
# ciudad
# segmento

# %% [markdown]
# BLOUQE 4:VALIDACIÓN DE DATOS

# %%
#Crear columna para registrar errores
df["motivo_rechazo"] = ""

#validar id_cliente
df.loc[df["id_cliente"].isnull(),"motivo_rechazo"] += "id_cliente nulos; "

# %%
import pandas as pd
from sqlalchemy import create_engine, text

DB_URL = "postgresql://etl_user:JAb9JP6gRc0RyRTCpEHmyb9prPFT7B4o@dpg-d6qu6r7gi27c73aaadlg-a.oregon-postgres.render.com/etl_seguros_68ir"
engine = create_engine(DB_URL)

# %%
engine = create_engine(DB_URL)

query_create = """
CREATE TABLE clientes(

id_cliente INT PRIMARY KEY,

nombre VARCHAR(150),

email VARCHAR(150),

genero VARCHAR(20),

fecha_nacimiento DATE,

ciudad VARCHAR(100),

segmento VARCHAR(50)

);
"""

try:
    with engine.connect() as connection:
        connection.execute(text(query_create))
        connection.commit()
        print("¡Tabla 'polizas' creada exitosamente en Render!")
except Exception as e:
    print(f"Error al crear la tabla: {e}")
# Out:
# ¡Tabla 'polizas' creada exitosamente en Render!
