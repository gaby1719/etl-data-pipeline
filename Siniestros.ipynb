# %% [markdown]
# <a href="https://colab.research.google.com/github/gaby1719/etl-data-pipeline/blob/main/Siniestros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url_siniestros = "https://raw.githubusercontent.com/gaby1719/etl-data-pipeline/refs/heads/main/data/raw/siniestros.csv"

# %%
siniestros = pd.read_csv(url_siniestros)

# %%
siniestros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4620 entries, 0 to 4619
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id_siniestro     4620 non-null   int64
#  1   id_poliza        4620 non-null   int64
#  2   fecha_siniestro  4620 non-null   object
#  3   monto_siniestro  4004 non-null   object
#  4   estado           3322 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.6+ KB

# %%
def limpiar_dataframe(df):



    df.columns = df.columns.str.strip().str.lower()



    for col in df.select_dtypes(include='object').columns:

        df[col] = df[col].astype(str).str.strip()



    df = df.replace(r'^\s*$', pd.NA, regex=True)



    df = df.drop_duplicates()



    return df

# %%
siniestros['fecha_siniestro'] = pd.to_datetime(

    siniestros['fecha_siniestro'], errors='coerce'

)
# Out:
# /tmp/ipykernel_296/348144693.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   siniestros['fecha_siniestro'] = pd.to_datetime(

# %%
siniestros.to_csv("siniestros_curated.csv", index=False)

# %%
import pandas as pd
from sqlalchemy import create_engine, text

DB_URL = "postgresql://etl_user:JAb9JP6gRc0RyRTCpEHmyb9prPFT7B4o@dpg-d6qu6r7gi27c73aaadlg-a.oregon-postgres.render.com/etl_seguros_68ir"
engine = create_engine(DB_URL)

# %%
engine = create_engine(DB_URL)

query_create = """
CREATE TABLE siniestros(

id_siniestro INT PRIMARY KEY,

id_poliza INT,

fecha_siniestro DATE,

monto_siniestro NUMERIC,

estado VARCHAR(50)

);
"""

try:
    with engine.connect() as connection:
        connection.execute(text(query_create))
        connection.commit()
        print("¡Tabla 'siniestros' creada exitosamente en Render!")
except Exception as e:
    print(f"Error al crear la tabla: {e}")
# Out:
# ¡Tabla 'siniestros' creada exitosamente en Render!

# %%
# !pip install sqlalchemy psycopg2-binary
from sqlalchemy import create_engine
engine = create_engine(
"postgresql://etl_user:JAb9JP6gRc0RyRTCpEHmyb9prPFT7B4o@dpg-d6qu6r7gi27c73aaadlg-a.oregon-postgres.render.com/etl_seguros_68ir"
)
